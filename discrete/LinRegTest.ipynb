# %%
import torch
import time
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    raise SystemError("GPU not found!")

# %%
n = 100  # Starting matrix size
increment = 100
tolerance = 1.0  # in seconds

while True:
    print(n)
    # Create random data
    X = torch.rand(n, n, device=device)
    y = torch.rand(n, 1, device=device)

    # Add a bias term (1) to X
    X_bias = torch.cat([torch.ones(n, 1, device=device), X], dim=1)

    start_time = time.time()

    # Apply the normal equation
    theta = torch.inverse(X_bias.T @ X_bias) @ X_bias.T @ y

    elapsed_time = time.time() - start_time

    if elapsed_time > tolerance:
        print(f"Maximum matrix size for GPU within 1 second using the direct formula: {n - increment}")
        break

    n += increment
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# Maximum matrix size for GPU within 1 second using the direct formula: 12000

# %%
np.random.seed(42)

# Parameters of dataset
m = 1000  
n = 50    
k = 10    
noise_std = 0.1

X = np.random.rand(m, n)

# Randomly select k columns from X
selected_columns_indices = np.random.choice(n, k, replace=False)
X_subset = X[:, selected_columns_indices]
coefficients = np.random.rand(k)
y_without_noise = X_subset @ coefficients
y = y_without_noise + np.random.normal(0, noise_std, m)

# %%
#constants
PLAYER1 = 1
PLAYER2 = -1
# Out:
# Estimated values: [0.384      0.50617284 0.79917095]
